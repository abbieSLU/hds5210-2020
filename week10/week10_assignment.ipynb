# %% [markdown]
# # Week 10 Assignment

# %%
#I do apologize for my late submission I thought it was due tomorrow at 11:59 with everything going on I totally lost track of time and my mind. Sorry again!

# %% [markdown]
# We had two major areas of discussion this week.  The first was all about how to work with string data - parsing and splitting strings using basic string fuctions as well as more complex string matching using regular expressions.  The second was a basic introduction to Pandas with a few different examples of how to load data into Pandas and then visualize it using graphs (histogram, distribution, scatter, bar, timeseries).
#
# * 36.1 - 1 point
# * 36.2 - 1 point
# * 38.1 - 3 points

# %% [markdown]
# ## 36.1 String Manipulation
#
# Write a function that will parse an address that includes one or two parts of street information, a city, a state, and a zip code -- all separated by commas.  You can assume that commas won't appear as part of the address information, only as a delimiter.  Here are some examples:
#
# 823 Pebble Street, St. Louis, MO 63105
#
# 91 Cityplace, Suite #33, St. Louis, MO 63144
#
# 81234 Homeroad, Kansas City, MO 62441
#
#
# The output you should generate will be a dictionary with the following possible items.
#
# ```
# {
#   'street1': '91 Cityplace',
#   'street2': 'Suite #33',
#   'city': 'St. Louis',
#   'state': 'MO',
#   'zip': '63122'
# }
# ```
#
# Declare your function like this:
# ```
# parse_address(address)
# ```

# %%
### YOUR SOLUTION

# %%
import json

def parse_address(result):
    
#result = '123 Main Street, Los Angeles, CA, 90034'
#result1='823 Pebble Street, St. Louis, MO, 63105'
    fun_sp = result.split(',')
    final = json.dumps({'street':fun_sp[0], 'city': fun_sp[1], 'state': fun_sp[2], 'zip': fun_sp[3]})
    print (final)#this is without the '' at the beginning and end

# %%
parse_address('823 Pebble Street, St. Louis, MO, 63105')
# Out:
# {"street": "823 Pebble Street", "city": " St. Louis", "state": " MO", "zip": " 63105"}

# %%
parse_address('91 Cityplace, Suite #33, St. Louis, MO, 63144')
# Out:
# {"street": "91 Cityplace", "city": " Suite #33", "state": " St. Louis", "zip": " MO"}

# %%
parse_address('81234 Homeroad, Kansas City, MO, 62441')
# Out:
# {"street": "81234 Homeroad", "city": " Kansas City", "state": " MO", "zip": " 62441"}

# %%
parse_address ('3750 West, Chicago, IL, 60632')
# Out:
# {"street": "3750 West", "city": " Chicago", "state": " IL", "zip": " 60632"}

# %%
import json

def parse_address(result):
    
#result = '123 Main Street, Los Angeles, CA, 90034'
#result1='823 Pebble Street, St. Louis, MO, 63105'
    fun_sp = result.split(',')
    final = json.dumps({'street':fun_sp[0], 'city': fun_sp[1], 'state': fun_sp[2], 'zip': fun_sp[3]})
    return (final)#the issue here is when you print (final) you do not get '' at the beginning and end

# %%
parse_address ('3750 West, Chicago, IL, 60632')
# Out:
# '{"street": "3750 West", "city": " Chicago", "state": " IL", "zip": " 60632"}'

# %% [markdown]
# ## 36.2 Test the Address Parser
#
# Now write a series of good tests to ensure that your addres parser is going to work with a variety of different inputs.  Include at least 5 different examples.

# %%
parse_address ('3750 West, Chicago, IL, 60632')=='{"street": "3750 West", "city": " Chicago", "state": " IL", "zip": " 60632"}'
# Out:
# True

# %%
parse_address('3949 Lindell, St. Louis, MO, 63108')=='{"street": "3949 Lindell", "city": " St. Louis", "state": " MO", "zip": " 63108"}'
# Out:
# True

# %%
parse_address('823 Pebble Street, St. Louis, MO, 63105')=='{"street": "823 Pebble Street", "city": " St. Louis", "state": " MO", "zip": " 63105"}'
# Out:
# True

# %%
parse_address('5330 South, Exeter, NH, 03833')=='{"street": "5330 South", "city": " Exeter", "state": " NH", "zip": " 03833"}'
# Out:
# True

# %%
parse_address('3443 West 54th Place, Chicago, IL, 60654')=='{"street": "3443 West 54th Place", "city": " Chicago", "state": " IL", "zip": " 60654"}'
# Out:
# True

# %% [markdown]
# ## 38.1 COVID-19 Trend Data
#
# Since we're dealing with a global pandemic right now, probably good to go ahead and do some anlysis with that data.  Take a look at what's here: https://ourworldindata.org/covid-sources-comparison
#
# Near the middle of the page, there are two charts with some data.  On the left is "positive cases" and on the right is "deaths."  Both charts have a button that says "Data."  What you will do below is write a series of Python commands (doesn't need to be in a function) to read that data and produce a simple timeseries chart using the information from John's Hopkins.  Your code will need to read the data, possibly do some reformatting, and then produce a simple timeseries chart.
#
# (Unfortunately, the tools used on this website don't make it easy to link to and directly download the data, so I've placed a copy in `/data/covid19.xlsx` for you to access.  This file came from one of the underlying sources: https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

dataset = pd.read_csv('covid-cases-by-source.csv', quotechar='"')

df= pd.DataFrame(dataset)
#data.shape
dataset.isnull()
dataset.isnull().sum()
modifiedDataset=df.fillna(0)#fills in the NAN spaces with blanks using( " ")

#dataset["Date"]=pd.to_datatime(dataset["Date"])


xdf=modifiedDataset.groupby("Date")["Johns Hopkins"].count()
#only selected Johns Hopkins data seem more accurate 
y_new=xdf.cumsum()
#xdf.plot(x='Date', y='Johns Hopkins')
#modifiedDataset=modifiedDataset.sort_values('Date',ascending=True)
#plt.plot(modifiedDataset['Date'],modifiedDataset['Johns Hopkins'])

y_new.plot(x='Date', y='Johns Hopkins')
z=modifiedDataset.groupby('Country').plot(x='Date', y='Johns Hopkins').cumsum()
xdf=modifiedDataset.groupby("Date")["Johns Hopkins"].count()
y=xdf.cumsum()
z=y.plot(x='Date', y='Johns Hopkins')
g = y.groupby(['Date']).plot(style='-')
# Out:
# /opt/tljh/user/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /opt/tljh/user/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# ...

# %%
#modifiedDataset.groupby('Country').plot(x='Date', y='Johns Hopkins').cumsum()

# %%
y_new

# %%
import pandas as pd


dataset = pd.read_csv('covid-cases-by-source.csv', quotechar='"')

modifiedDataset=df.fillna(0)

#modifiedDataset["Date"]= pd.to_datatime(modifiedDataset["Date"]) to convert

# %%
modifiedDataset
# Out:
#            Country Code       Date  Johns Hopkins  WHO (cases)  ECDC (cases)
# 0      Afghanistan  AFG  31-Dec-19            0.0          0.0           0.0
# 1      Afghanistan  AFG   1-Jan-20            0.0          0.0           0.0
# 2      Afghanistan  AFG   2-Jan-20            0.0          0.0           0.0
# 3      Afghanistan  AFG   3-Jan-20            0.0          0.0           0.0
# 4      Afghanistan  AFG   4-Jan-20            0.0          0.0           0.0
# ...            ...  ...        ...            ...          ...           ...
# 12849     Zimbabwe  ZWE  23-Mar-20            0.0          0.0           2.0
# 12850     Zimbabwe  ZWE  24-Mar-20            0.0          0.0           2.0
# 12851     Zimbabwe  ZWE  25-Mar-20            0.0          0.0           2.0
# 12852     Zimbabwe  ZWE  26-Mar-20            0.0          0.0           3.0
# 12853     Zimbabwe  ZWE  27-Mar-20            0.0          0.0           3.0
#
# [12854 rows x 6 columns]

# %%
print(dataset.dtypes)#find out types 
#dataset['Date'].head()
modifiedDataset['Date'].head()
# Out:
# Country           object
# Code              object
# Date              object
# Johns Hopkins    float64
# WHO (cases)      float64
# ECDC (cases)     float64
# dtype: object
# 0    31-Dec-19
# 1     1-Jan-20
# 2     2-Jan-20
# 3     3-Jan-20
# 4     4-Jan-20
# Name: Date, dtype: object

# %%
xdf=modifiedDataset.groupby("Date")["Johns Hopkins"].count()
y=xdf.cumsum()
z=y.plot(x='Date', y='Johns Hopkins')
g = y.groupby(['Date']).plot(style='-')

# %% [markdown]
# One hint that you might find helpful while working on this is that the data in this file is the number of cases each week, not the running total.  You will want to plot a running total.
#
# To do so, pandas has a `.cumsum()` method that you can use after doing a `groupby` and a `.sum()` somewhat similar to the last example of the pandas-viz.ipynb file (except in that example, it's doing a `mean()` instead of `sum()` and a `rolling()` instead of `cumsum()`.)  This link might also provide a little guidance: https://stackoverflow.com/questions/48739374/pandas-plot-cumulative-sum-of-counters-over-time

# %% [markdown]
# ## Extra Challenges
#
# Take the same data, but not start looking at it by country.  Do some groupbys.
#
# Or take the same data and look at the mortality rate (deaths / total reported cases) and see how that is different by country or trending over time.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

dataset = pd.read_csv('deaths-from-covid-by-source.csv', quotechar='"')

bf= pd.DataFrame(dataset)
#data.shape
dataset.isnull()
dataset.isnull().sum()
modifiedDataset=bf.fillna(0)#fills in the NAN spaces with blanks using( " ")

#dataset["Date"]=pd.to_datatime(dataset["Date"])


bdf=modifiedDataset.groupby("Date")["Johns Hopkins"].count()
#only selected Johns Hopkins data seem more accurate 

#xdf.plot(x='Date', y='Johns Hopkins')
#modifiedDataset=modifiedDataset.sort_values('Date',ascending=True)
#plt.plot(modifiedDataset['Date'],modifiedDataset['Johns Hopkins'])

a= bdf.groupby(['Date']).mean().plot(style='*')
a.set_ylim(0,100)

bdf=modifiedDataset.groupby("Date")["Johns Hopkins"].count()
y=bdf.cumsum()
z=y.plot(x='Date', y='Johns Hopkins')
g = y.groupby(['Date']).plot(style='-')
#g_new=y_new.groupby(['Date']).plot(style='*')

new_bdf=modifiedDataset.groupby("Date")["Johns Hopkins"].plot()

# %%
a= bdf.groupby(['Date']).mean().plot(style='*')

# %%
b=modifiedDataset.groupby("Entity")["Johns Hopkins"].plot()
